# %%
import json
# 네이버 쇼핑에서, android 라는 키워드로 검색한 상품 리스트 결과

data = """
{
    "lastBuildDate": "Thu, 06 May 2021 14:43:39 +0900",
    "total": 582301,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "올해 수입차 10대 중 3대는 하이브리드…친환경 트렌드에 디젤 넘고 '훨훨'",
            "originallink": "http://www.sisaon.co.kr/news/articleView.html?idxno=127131",
            "link": "http://www.sisaon.co.kr/news/articleView.html?idxno=127131",
            "description": "이러한 추세는 친환경 전동화 시대 도래로 인해 디젤 선호도가 낮아진 틈을 파고든 것은 물론 <b>전기차</b>의... 한 업계 관계자는 &quot;친환경 트렌드가 <b>전기차</b> 일변도로 흘러가는 것이 아니라, 내연기관과 <b>전기차</b>의 중간... ",
            "pubDate": "Thu, 06 May 2021 14:40:00 +0900"
        },
        {
            "title": "수원시, <b>전기차</b> 충전소 정보 제공 공공데이터 구축 박차",
            "originallink": "http://www.newsworks.co.kr/news/articleView.html?idxno=546875",
            "link": "http://www.newsworks.co.kr/news/articleView.html?idxno=546875",
            "description": "<b>전기차</b> 충전소 위치나 기종, 품질 등 관련 정보를 한눈에 볼 수 있는 공공데이터를 구축해 민간 부문에서도 이를 활용할 수 있도록 공개한다. 수원시는 행정안전부의 '2021년 데이터 기업매칭 지원사업' 공모에서 '<b>전기차</b>... ",
            "pubDate": "Thu, 06 May 2021 14:40:00 +0900"
        },
        {
            "title": "고양시, <b>전기차</b> 충전인프라 늘려 탄소중립 실천한다",
            "originallink": "http://www.weeklytoday.com/news/articleView.html?idxno=363579",
            "link": "http://www.weeklytoday.com/news/articleView.html?idxno=363579",
            "description": "▲ 고양시, <b>전기차</b> 충전인프라 늘려 탄소중립 실천한다  고양시는 탄소중립 이행을 위해 <b>전기차</b> 충전 인프라를 확충하고 있다고 밝혔다. 시는 정부의 그린뉴딜 정책에 발맞춰 친환경차 보급 대수를 점진적으로... ",
            "pubDate": "Thu, 06 May 2021 14:40:00 +0900"
        },
        {
            "title": "2021년 4월 수입차 판매 11.5%↑… “두 자릿수 성장에도 웃지 못하는 이유”",
            "originallink": "https://www.donga.com/news/article/all/20210506/106792301/2",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=103&oid=020&aid=0003355866",
            "description": "플러그인하이브리드 모델은 1811대로 7.1%, <b>전기차</b>는 510대로 2.0% 비중을 기록했다. 임한규 한국수입차협회 부회장은 “지난달 수입차 신규등록대수는 성장세를 이어갔지만 1분기에 비해 성장률이 둔화된 모습을... ",
            "pubDate": "Thu, 06 May 2021 14:39:00 +0900"
        },
        {
            "title": "테슬라 좋은 시절 다 갔다…최대 수익원 탄소배출권 판매 급감 탓",
            "originallink": "https://www.seoul.co.kr/news/newsView.php?id=20210506500092&wlog_tag3=naver",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=081&aid=0003184492",
            "description": "지금까지 테슬라는 <b>전기차</b> 판매가 아니라 탄소배출권 판매 수익으로 순익을 내왔다고 해도 과언이... 독일의 폭스바겐 뿐 아니라 미국의 제너럴모터스(GM) 등 기존의 글로벌 완성차 업체 강자들이 잇따라 <b>전기차</b> 시장... ",
            "pubDate": "Thu, 06 May 2021 14:37:00 +0900"
        },
        {
            "title": "광양시, 포스코 리튬솔루션(주)과 '대규모 투자협약' 체결",
            "originallink": "http://www.newsworker.co.kr/news/articleView.html?idxno=112862",
            "link": "http://www.newsworker.co.kr/news/articleView.html?idxno=112862",
            "description": "먹거리인 <b>전기차</b> 배터리 중심의 국내외 이차전지 산업을 주도하는 기업으로 발전하길 기원한다&quot;고 말했다. 광양시는 5월 현재 기준 6개 기업에 7,843억 원, 344명의 투자유치를 이뤄냈으며, 올해 목표인 30개 기업, 1조... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "한국지엠 이달 임금협상 개시…노사 갈등 재현 먹구름",
            "originallink": "http://www.skyedaily.com/news/news_view.html?ID=130498",
            "link": "http://www.skyedaily.com/news/news_view.html?ID=130498",
            "description": "특히 부평2공장의 경우 내년 4분기부터 내연기관차와 <b>전기차</b> 등 생산 물량을 신규로 배정해 줄 것을 약속해 달라고 요구하기로 했다. 현재 부평2공장은 생산 일정이 내년 7월까지만 잡혀 있다. 이에 해당 공장 직원들... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "광양시·포스코 리튬솔루션, 7600억 투자협약",
            "originallink": "https://daily.hankooki.com/lpage/society/202105/dh20210506142518148510.htm?s_ref=nv",
            "link": "https://daily.hankooki.com/lpage/society/202105/dh20210506142518148510.htm?s_ref=nv",
            "description": "먹거리인 <b>전기차</b> 배터리 중심의 국내외 이차전지 산업을 주도하는 기업으로 발전하길 기원한다”고 말했다. 광양시는 5월 현재 기준 6개 기업에 7843억원, 344명의 투자유치를 이뤄냈으며, 올해 목표인 30개 기업, 1조... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "카카오, 올해 투자 속도 높인다...1분기 역대 최고 실적 달성",
            "originallink": "http://www.aitimes.com/news/articleView.html?idxno=138390",
            "link": "http://www.aitimes.com/news/articleView.html?idxno=138390",
            "description": "카카오 내비게이션을 통해 차량 정비, 방문 세차, <b>전기차</b> 충전, 내 차 팔기 등 신규 서비스도 추진 중이다. 올해 상반기부터는 퀵서비스 사업을 기업 대상으로 출시할 예정이다. 렌터카와 반려동물 택시 사업 등 신규... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "[6일 오후 특징주] 동양3우B‧동일제강‧대원전선우‧대호특수강우 등 8종목 ...",
            "originallink": "http://www.kpinews.co.kr/news/articleView.html?idxno=146091",
            "link": "http://www.kpinews.co.kr/news/articleView.html?idxno=146091",
            "description": "현대자동차가 최신 <b>전기차</b> '아이오닉5'를 통해 중국 <b>전기차</b> 시장 공략에 본격적으로 나서며 전선을 공급하는 대원전선이 수혜를 볼 것이란 기대감이 높아진 결과로 보인다. 대호특수강우는 전 거래일 보다 29.72... ",
            "pubDate": "Thu, 06 May 2021 14:30:00 +0900"
        }
    ]
}


"""
json_data = json.loads(data)
print(json_data['items'][0]['title'])
print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 올해 수입차 10대 중 3대는 하이브리드…친환경 트렌드에 디젤 넘고 '훨훨'
# http://www.sisaon.co.kr/news/articleView.html?idxno=127131
# 이러한 추세는 친환경 전동화 시대 도래로 인해 디젤 선호도가 낮아진 틈을 파고든 것은 물론 <b>전기차</b>의... 한 업계 관계자는 &quot;친환경 트렌드가 <b>전기차</b> 일변도로 흘러가는 것이 아니라, 내연기관과 <b>전기차</b>의 중간...

# %%
import requests
import pprint

client_id = 'MctXCT4gG5nJVvszXR0S'
client_secret = '6Kca0m6a5O'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=전기차'
header_params = {'X-naver-client-id':client_id, 'X-naver-client-secret':client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index+1, item['title'], item['link'])
else:
    print("Error Code", res.status_code)
# Out:
# 1 수원시 <b>전기차</b> 충전소 정보 한눈에...&quot;공공데이터, 민간에 공개&quot; http://www.ifm.kr/news/308122
# 2 아우디, 새로운 전기구동 스포츠 모델로 2023년 르망 24시간 레이스 복귀 http://www.metroseoul.co.kr/article/20210506500481
# 3 고양시, <b>전기차</b> 충전인프라 늘려 탄소중립 실천한다 https://www.dnews.co.kr/uhtml/view.jsp?idxno=202105061459547210105
# 4 쎄보모빌리티, 신형 초소형 <b>전기차</b> CEVO-C SE 정식계약 돌입 http://www.lawissue.co.kr/view.php?ud=202105061509108927204ead0791_12
# 5 수입車, 친환경 `가속 페달`‥1년 새 253% 증가 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=103&oid=018&aid=0004922045
# 6 수소<b>전기차</b> 충전소 그린벨트 내 설치 허용 http://www.jeonmin.co.kr/news/articleView.html?idxno=331134
# 7 광양서 '리튬' 생산한다...포스코리튬솔루션과 7천600억 규모 투자협약 http://www.thekpm.com/view.php?ud=2021050614390372905cb205d37d_17
# 8 4월 수입차 신규 등록대수 2만5578대…&quot;벤츠, 베스트셀링 순위권 싹쓸이&quot; http://www.newsworks.co.kr/news/articleView.html?idxno=546886
# 9 한국GM 노사, 올해 임금협상 교섭 시작...난항 예상 http://www.jeonmae.co.kr/news/articleView.html?idxno=839281
# ...

# %%
import requests
import pprint

client_id = 'MctXCT4gG5nJVvszXR0S'
client_secret = '6Kca0m6a5O'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=전기차&display=100&start=1'
## 요청 변수 (request parameter) 변경해서 검색어 100개 뽑아보기
header_params = {'X-naver-client-id':client_id, 'X-naver-client-secret':client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index+1, item['title'], item['link'])
#         pprint.pprint(data['items'])
else:
    print("Error Code", res.status_code)
# Out:
# 1 화성도시공사, 국내 최초 융복합 스마트에너지 사업 공동 개발 추진 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0003099540
# 2 LS일렉트릭 이번에는 <b>전기차</b> 때 만나, 구자균 충전사업 다시 시동거나 https://www.businesspost.co.kr/BP?command=article_view&num=230307
# 3 [이슈] 배터리-렌터카 '합종연횡' 배경은? http://www.seoulfn.com/news/articleView.html?idxno=418880
# 4 이차전지 소재 경쟁력 확보 청신호 http://www.jndn.com/article.php?aid=1620289812316268001
# 5 대창모터스 &quot;<b>전기차</b> 年 1만 대 공장 착공&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004542211
# 6 &quot;차는 안팔리고 노사갈등은 반복되고&quot;…車시장 양극화 심화 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000956085
# 7 광양시, 포스코 리튬솔루션(주)과 대규모 투자협약 http://www.sisamagazine.co.kr/news/articleView.html?idxno=356567
# 8 첨단산업의 심장 '리튬' 광양서 생산한다 https://www.jnilbo.com/view/media/view?code=2021050617223100519
# 9 질주하던 테슬라, '탄소배출권·獨기가팩토리' 악재에 제동 걸리나 http://www.sisajournal-e.com/news/articleView.html?idxno=231905
# ...

# %% [markdown]
# ### 실무에 사용되는 크롤링 실용코드 이해하기

# %%
import requests
import openpyxl

client_id = 'MctXCT4gG5nJVvszXR0S'
client_pw = '6Kca0m6a5O'
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['넘버','제목','링크'])

for index in range(10):
    start_number = start + (index *100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=전기차&display=100&start='+ str(start_number)
    header_params = {'X-naver-client-id':client_id, 'X-naver-client-secret':client_pw}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num +=1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print("Error Code:", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close
# Out:
# <bound method Workbook.close of <openpyxl.workbook.workbook.Workbook object at 0x000001CC4A8FE730>>

# %%
import requests
import openpyxl

client_id = 'MctXCT4gG5nJVvszXR0S'
client_pw = '6Kca0m6a5O'
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['넘버','제목','링크'])

for index in range(10):
    start_number = start + (index *100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=가상화폐&display=100&start='+ str(start_number)
    header_params = {'X-naver-client-id':client_id, 'X-naver-client-secret':client_pw}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num +=1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print("Error Code:", res.status_code)
excel_file.save('IT(1).xlsx')
excel_file.close
# Out:
# <bound method Workbook.close of <openpyxl.workbook.workbook.Workbook object at 0x000001CC4A8FE6A0>>

# %% [markdown]
# * 위의 코드 api 사용량 10개씩 잡아먹음 -- 이유 생각해보기
